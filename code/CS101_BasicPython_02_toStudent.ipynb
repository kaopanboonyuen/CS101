# %% [markdown]
# # CS101 Python Tutorial With Google Colab
#
# ![](https://raw.githubusercontent.com/kaopanboonyuen/CS101/main/img/python_coding.gif)

# %% [markdown]
# Reference:
#
# - https://stanfordpython.com
# - https://ocw.mit.edu/courses/6-0001-introduction-to-computer-science-and-programming-in-python-fall-2016/
# - https://stanford.edu/~schmit/cme193/
# - https://github.com/suneelpatel/Python-for-Beginners/tree/master
# - https://data-flair.training/blogs/python-career-opportunities/
# - https://geekflare.com/google-colab/
# - https://cs231n.github.io/python-numpy-tutorial/
# - https://www.cp.eng.chula.ac.th/books/python101/

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# ## Basics of Python

# %% [markdown]
# ### Booleans

# %% [markdown]
# Python implements all of the usual operators for Boolean logic, but uses English words rather than symbols (`&&`, `||`, etc.):
#
# ##### Comparison Operations
#
# | Operation     | Description                       || Operation     | Description                          |
# |---------------|-----------------------------------||---------------|--------------------------------------|
# | ``a == b``    | ``a`` equal to ``b``              || ``a != b``    | ``a`` not equal to ``b``             |
# | ``a < b``     | ``a`` less than ``b``             || ``a > b``     | ``a`` greater than ``b``             |
# | ``a <= b``    | ``a`` less than or equal to ``b`` || ``a >= b``    | ``a`` greater than or equal to ``b`` |

# %%
t, f = True, False
print(type(t))
# Out:
# <class 'bool'>

# %% [markdown]
# Now we let's look at the operations:

# %%
print(t and f) # Logical AND;
print(t or f)  # Logical OR;
print(not t)   # Logical NOT;
print(t != f)  # Logical XOR;
# Out:
# False
# True
# False
# True

# %%
print(bool(1)) # all numbers are treated as true, except 0
print(bool(0))
print(bool("asf")) # all strings are treated as true, except the empty string ""
print(bool(""))
# Out:
# True
# False
# True
# False

# %%
# Boolean example
is_raining = True
is_sunny = False

if is_raining and not is_sunny:
    print("Remember to take an umbrella.")
else:
    print("Enjoy your day!")
# Out:
# Remember to take an umbrella.

# %% [markdown]
# ### Strings

# %% [markdown]
# String objects have a bunch of useful methods; for example:
#
# ![](https://www.alphacodingskills.com/python/img/python-string.png)

# %%
# String concatenation example
name = "Kao"
greeting = "Hello, " + name + "!"
print(greeting)
# Out:
# Hello, Kao!

# %%
# String length example
message = "Hello, AI!"
length = len(message)
print("Length:", length)
# Out:
# Length: 10

# %%
# String formatting example
name = "Bob"
age = 25
formatted_string = "My name is {} and I'm {} years old.".format(name, age)
print(formatted_string)
# Out:
# My name is Bob and I'm 25 years old.

# %%
# String slicing example
text = 'Dokkoisho is something like the Japanese version of heave-ho'
sliced_text = text[0:6]
print("Sliced Text:", sliced_text)
sliced_text = text[6:]
print("Sliced Text:", sliced_text)
sliced_text = text[-11:-1]
print("Sliced Text:", sliced_text)
sliced_text = text[::2] # Slicing with a step size of 2
print("Sliced Text:", sliced_text)
reversed_text = text[::-1] # Reversing the string using slicing
print("Reversed Text:", reversed_text)
# Out:
# Sliced Text: Dokkoi
# Sliced Text: sho is something like the Japanese version of heave-ho
# Sliced Text: of heave-h
# Sliced Text: Dkosoi oehn ieteJpns eso fhaeh
# Reversed Text: oh-evaeh fo noisrev esenapaJ eht ekil gnihtemos si ohsiokkoD

# %%
# String joining example
words = ["Hello", "World", "Python"]
joined_string = " ".join(words)
print("Joined String:", joined_string)
# Out:
# Joined String: Hello World Python

# %%
s = "pythonProgramming"
print(s.capitalize())  # Capitalize a string
print(s.upper())       # Convert a string to uppercase; prints "HELLO"
print(s.rjust(21))      # Right-justify a string, padding with spaces
print(s.center(21))     # Center a string, padding with spaces
print(s.replace('python', 'golang'))  # Replace all instances of one substring with another
print('  python '.strip())  # Strip leading and trailing whitespace
# Out:
# Pythonprogramming
# PYTHONPROGRAMMING
#     pythonProgramming
#   pythonProgramming
# golangProgramming
# python

# %%
text = "FUJI is a spun silk clothing fabric in plain weave originally made in Japan."

# 1. len() - Returns the length of the string
length = len(text)
print("Length:", length)

# 2. upper() - Converts the string to uppercase
uppercase_text = text.upper()
print("Uppercase:", uppercase_text)

# 3. lower() - Converts the string to lowercase
lowercase_text = text.lower()
print("Lowercase:", lowercase_text)

# 4. count() - Counts the occurrences of a substring in the string
count_occurrences = text.count('FUJI')
print("Occurrences of 'FUJI':", count_occurrences)

# 5. find() - Finds the first occurrence of a substring in the string
first_occurrence = text.find('fabric')
print("First occurrence of 'fabric':", first_occurrence)

# 6. replace() - Replaces a substring with another substring
replaced_text = text.replace('Japan',  'ญี่ปุ่น')
print("Replaced text:", replaced_text)

# 7. split() - Splits the string into a list of substrings based on a delimiter
splitted_text = text.split()
print("Splitted text:", splitted_text)

# 8. isalpha() - Checks if the string contains only alphabetic characters
is_alpha = text.isalpha()
print("Is alpha?", is_alpha)

# 9. isnumeric() - Checks if the string contains only numeric characters
is_numeric = text.isnumeric()
print("Is numeric?", is_numeric)

# 10. startswith() - Checks if the string starts with a specific substring
starts_with = text.startswith('plain')
print("Starts with plain", starts_with)
# Out:
# Length: 76
# Uppercase: FUJI IS A SPUN SILK CLOTHING FABRIC IN PLAIN WEAVE ORIGINALLY MADE IN JAPAN.
# Lowercase: fuji is a spun silk clothing fabric in plain weave originally made in japan.
# Occurrences of 'FUJI': 1
# First occurrence of 'fabric': 29
# Replaced text: FUJI is a spun silk clothing fabric in plain weave originally made in ญี่ปุ่น.
# Splitted text: ['FUJI', 'is', 'a', 'spun', 'silk', 'clothing', 'fabric', 'in', 'plain', 'weave', 'originally', 'made', 'in', 'Japan.']
# Is alpha? False
# Is numeric? False
# Starts with plain False

# %% [markdown]
# You can find a list of all string methods in the [documentation](https://docs.python.org/3.7/library/stdtypes.html#string-methods).

# %% [markdown]
# ### Condition

# %%
# Grade Classifier:

score = int(input("Enter the student's score: "))

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

print("The student's grade is:", grade)
# Out:
# Enter the student's score: 11
# The student's grade is: F

# %%
# Leap Year Checker:

year = int(input("Enter a year: "))

if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# Enter a year: 11
# 11 is not a leap year.

# %%
# Positive or Negative:

number = int(input("Enter a number: "))

if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: 11
# The number is positive.

# %%
# Vowel or Consonant:

letter = input("Enter a letter: ")

if letter.lower() in 'aeiou':
    print("The letter is a vowel.")
else:
    print("The letter is a consonant.")
# Out:
# Enter a letter: 10
# The letter is a consonant.

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number: 2023
# The number is odd.

# %% [markdown]
# ### Optional: Flowcharts
#
# https://problemsolvingwithpython.com/08-If-Else-Try-Except/08.06-Flowcharts/

# %% [markdown]
# ### Loops

# %%
# Example of a while loop
count = 0
while count < 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4

# %%
# Example of a for loop
numbers = [1, 2, 3, 4, 5]
for number in numbers:
    print("Number:", number)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5

# %%
# Example of nested loops
rows = 3
columns = 3

for i in range(rows):
    for j in range(columns):
        print(f"({i}, {j})")
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)
# (2, 0)
# (2, 1)
# (2, 2)

# %% [markdown]
# #### Exercise 2: Consonant and Vowels
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX2-1.png)

# %%
# EXERCISE2: Insert your code here

# %% [markdown]
# #### Exercise 3: Find a string
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX3-1.png)

# %%
# EXERCISE3: Insert your code here

# %% [markdown]
# #### Exercise 4: Count Uppercase Characters
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX4-1.png)

# %%
# EXERCISE4: Insert your code here

# %% [markdown]
# #### Exercise 5: Simple Grade
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX5-1.png)
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX5-2.png)

# %%
# EXERCISE5: Insert your code here

# %% [markdown]
# ### Containers

# %% [markdown]
# Python includes several built-in container types: lists, dictionaries, sets, and tuples.
#
# ![](https://www.aipython.in/wp-content/uploads/2020/02/Index_in_python-list.png)

# %% [markdown]
# #### Lists

# %% [markdown]
# A list is the Python equivalent of an array, but is resizeable and can contain elements of different types:

# %%
xs = [3, 1, 2]   # Create a list
print(xs, xs[2])
print(xs[-1])     # Negative indices count from the end of the list; prints "2"
# Out:
# [3, 1, 2] 2
# 2

# %%
xs[2] = 'foo'    # Lists can contain elements of different types
print(xs)
# Out:
# [3, 1, 'foo']

# %%
xs.append('bar') # Add a new element to the end of the list
print(xs)
# Out:
# [3, 1, 'foo', 'bar']

# %%
x = xs.pop()     # Remove and return the last element of the list
print(x, xs)
# Out:
# bar [3, 1, 'foo']

# %% [markdown]
# As usual, you can find all the gory details about lists in the [documentation](https://docs.python.org/3.7/tutorial/datastructures.html#more-on-lists).

# %% [markdown]
# #### Slicing

# %% [markdown]
# In addition to accessing list elements one at a time, Python provides concise syntax to access sublists; this is known as slicing:

# %%
nums = list(range(5))    # range is a built-in function that creates a list of integers
print(nums)         # Prints "[0, 1, 2, 3, 4]"
print(nums[2:4])    # Get a slice from index 2 to 4 (exclusive); prints "[2, 3]"
print(nums[2:])     # Get a slice from index 2 to the end; prints "[2, 3, 4]"
print(nums[:2])     # Get a slice from the start to index 2 (exclusive); prints "[0, 1]"
print(nums[:])      # Get a slice of the whole list; prints ["0, 1, 2, 3, 4]"
print(nums[:-1])    # Slice indices can be negative; prints ["0, 1, 2, 3]"
nums[2:4] = [8, 9] # Assign a new sublist to a slice
print(nums)         # Prints "[0, 1, 8, 9, 4]"
# Out:
# [0, 1, 2, 3, 4]
# [2, 3]
# [2, 3, 4]
# [0, 1]
# [0, 1, 2, 3, 4]
# [0, 1, 2, 3]
# [0, 1, 8, 9, 4]

# %% [markdown]
# #### Loops

# %% [markdown]
# You can loop over the elements of a list like this:

# %%
animals = ['cat', 'dog', 'monkey']
for animal in animals:
    print(animal)
# Out:
# cat
# dog
# monkey

# %% [markdown]
# If you want access to the index of each element within the body of a loop, use the built-in `enumerate` function:

# %%
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print('#{}: {}'.format(idx + 1, animal))
# Out:
# #1: cat
# #2: dog
# #3: monkey

# %% [markdown]
# #### List comprehensions:

# %% [markdown]
# When programming, frequently we want to transform one type of data into another. As a simple example, consider the following code that computes square numbers:

# %%
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x ** 2)
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# You can make this code simpler using a list comprehension:

# %%
nums = [0, 1, 2, 3, 4]
squares = [x ** 2 for x in nums]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# List comprehensions can also contain conditions:

# %%
nums = [0, 1, 2, 3, 4]
even_squares = [x ** 2 for x in nums if x % 2 == 0]
print(even_squares)
# Out:
# [0, 4, 16]

# %% [markdown]
# #### Dictionaries

# %% [markdown]
# A dictionary stores (key, value) pairs, similar to a `Map` in Java or an object in Javascript. You can use it like this:

# %%
d = {'cat': 'cute', 'dog': 'furry'}  # Create a new dictionary with some data
print(d['cat'])       # Get an entry from a dictionary; prints "cute"
print('cat' in d)     # Check if a dictionary has a given key; prints "True"
# Out:
# cute
# True

# %%
d['fish'] = 'wet'    # Set an entry in a dictionary
print(d['fish'])      # Prints "wet"
# Out:
# wet

# %%
# print(d['monkey'])  # KeyError: 'monkey' not a key of d

# %%
print(d.get('monkey', 'N/A'))  # Get an element with a default; prints "N/A"
print(d.get('fish', 'N/A'))    # Get an element with a default; prints "wet"
# Out:
# N/A
# wet

# %%
del d['fish']        # Remove an element from a dictionary
print(d.get('fish', 'N/A')) # "fish" is no longer a key; prints "N/A"
# Out:
# N/A

# %% [markdown]
# You can find all you need to know about dictionaries in the [documentation](https://docs.python.org/2/library/stdtypes.html#dict).

# %% [markdown]
# It is easy to iterate over the keys in a dictionary:

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal, legs in d.items():
    print('A {} has {} legs'.format(animal, legs))
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %% [markdown]
# Dictionary comprehensions: These are similar to list comprehensions, but allow you to easily construct dictionaries. For example:

# %%
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)
# Out:
# {0: 0, 2: 4, 4: 16}

# %% [markdown]
# #### Sets

# %% [markdown]
# A set is an unordered collection of distinct elements. As a simple example, consider the following:

# %%
animals = {'cat', 'dog'}
print('cat' in animals)   # Check if an element is in a set; prints "True"
print('fish' in animals)  # prints "False"
# Out:
# True
# False

# %%
animals.add('fish')      # Add an element to a set
print('fish' in animals)
print(len(animals))       # Number of elements in a set;
# Out:
# True
# 3

# %%
animals.add('cat')       # Adding an element that is already in the set does nothing
print(len(animals))
animals.remove('cat')    # Remove an element from a set
print(len(animals))
# Out:
# 3
# 2

# %% [markdown]
# _Loops_: Iterating over a set has the same syntax as iterating over a list; however since sets are unordered, you cannot make assumptions about the order in which you visit the elements of the set:

# %%
animals = {'cat', 'dog', 'fish'}
for idx, animal in enumerate(animals):
    print('#{}: {}'.format(idx + 1, animal))
# Out:
# #1: cat
# #2: dog
# #3: fish

# %% [markdown]
# Set comprehensions: Like lists and dictionaries, we can easily construct sets using set comprehensions:

# %%
from math import sqrt
print({int(sqrt(x)) for x in range(30)})
# Out:
# {0, 1, 2, 3, 4, 5}

# %% [markdown]
# #### Tuples

# %% [markdown]
# A tuple is an (immutable) ordered list of values. A tuple is in many ways similar to a list; one of the most important differences is that tuples can be used as keys in dictionaries and as elements of sets, while lists cannot. Here is a trivial example:

# %%
d = {(x, x + 1): x for x in range(10)}  # Create a dictionary with tuple keys
t = (5, 6)       # Create a tuple
print(type(t))
print(d[t])
print(d[(1, 2)])
# Out:
# <class 'tuple'>
# 5
# 1

# %%
# t[0] = 1

# %% [markdown]
# ### Functions

# %% [markdown]
# Python functions are defined using the `def` keyword. For example:

# %%
def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    else:
        return 'zero'

for x in [-1, 0, 1]:
    print(sign(x))
# Out:
# negative
# zero
# positive

# %%
def calculate_sum(numbers):
    
    # Insert your code here
    
    return total

my_list = [1, 2, 3, 4, 5]
result = calculate_sum(my_list)
print("The sum is:", result)

# %% [markdown]
# ![](https://smartcdn.gprod.postmedia.digital/calgaryherald/wp-content/uploads/2020/01/76677518-palindrome_page-0001_copy-w.jpg)

# %%
def is_palindrome(word):
    
    # Insert your code here
    
    return word

word = input("Enter a word: ")
if is_palindrome(word):
    print("It is a palindrome!")
else:
    print("It is not a palindrome.")

# %% [markdown]
# We will often define functions to take optional keyword arguments, like this:

# %%
def hello(name, loud=False):
    if loud:
        print('HELLO, {}'.format(name.upper()))
    else:
        print('Hello, {}!'.format(name))

hello('Bob')
hello('Fred', loud=True)
# Out:
# Hello, Bob!
# HELLO, FRED

# %% [markdown]
# #### Exercise 6: Find the mean of n numbers
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX6-1.png)

# %%
# EXERCISE6: Insert your code here

# %% [markdown]
# #### Exercise 7: BMI with Loop Condition
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX7-1.png)

# %%
# EXERCISE7: Insert your code here

# %% [markdown]
# #### Exercise 8: Count the number of digits
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX8-1.png)

# %%
# EXERCISE8: Insert your code here

# %% [markdown]
# #### Exercise 9: Date Conversion
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX9-1.png)

# %%
# EXERCISE9: Insert your code here

# %% [markdown]
# #### Exercise 10: Find the evenly divisible number
#
# ![](https://github.com/kaopanboonyuen/CS101/raw/main/img/exercise/EX10-1.png)

# %%
# EXERCISE10: Insert your code here

# %% [markdown]
# ### Classes

# %% [markdown]
# The syntax for defining classes in Python is straightforward:

# %%
class Greeter:

    # Constructor
    def __init__(self, name):
        self.name = name  # Create an instance variable

    # Instance method
    def greet(self, loud=False):
        if loud:
          print('HELLO, {}'.format(self.name.upper()))
        else:
          print('Hello, {}!'.format(self.name))

g = Greeter('Fred')  # Construct an instance of the Greeter class
g.greet()            # Call an instance method; prints "Hello, Fred"
g.greet(loud=True)   # Call an instance method; prints "HELLO, FRED!"
# Out:
# Hello, Fred!
# HELLO, FRED
